# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('fifa21_train.csv')
data
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
#         BP   Position                               Team & Contract Height  \
# 0       CM     CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"
# 1       ST   ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"
# 2      CAM     CAM CF                          Al Hilal 2019 ~ 2022   5'4"
# 3      CDM     CDM CM                      Swansea City 2016 ~ 2021  5'10"
# 4      CDM     CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"
# ...    ...        ...                                           ...    ...
# 11696   LB         LB             Jagiellonia Białystok 2018 ~ 2021   6'1"
# 11697   GK         GK                      ESTAC Troyes 2019 ~ 2022   6'1"
# 11698   RM  LM CAM RM                    CD Antofagasta 2019 ~ 2024   5'6"
# 11699   CM        NaN                                 Barnsley 2010   6'2"
# 11700  CAM  ST CAM LM                  Portland Timbers 2019 ~ 2020   5'7"
#
#        Weight  ...   CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0      161lbs  ...  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1      159lbs  ...  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2      134lbs  ...  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
# 3      152lbs  ...  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2   59
# 4      150lbs  ...  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2   65
# ...       ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 11696  168lbs  ...  60+2  60+2  63+2  63+2  61+2  61+2  61+2  63+2  16+2   65
# 11697  174lbs  ...  26+2  26+2  25+2  24+2  26+2  26+2  26+2  24+2  69+2   70
# 11698  143lbs  ...  44+2  44+2  49+2  45+2  35+2  35+2  35+2  45+2  17+2   67
# 11699  179lbs  ...  68+0  68+0  66+0  64+0  60+0  60+0  60+0  64+0  25+0   68
# 11700  143lbs  ...  43+2  43+2  46+2  44+2  36+2  36+2  36+2  44+2  15+2   64
#
# [11701 rows x 101 columns]

# %%
def cleanfifa(data):
    data = data.drop_duplicates()
    mean_value=data.mean()
    data.fillna(value=mean_value, inplace=True) 

data
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
#         BP   Position                               Team & Contract Height  \
# 0       CM     CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"
# 1       ST   ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"
# 2      CAM     CAM CF                          Al Hilal 2019 ~ 2022   5'4"
# 3      CDM     CDM CM                      Swansea City 2016 ~ 2021  5'10"
# 4      CDM     CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"
# ...    ...        ...                                           ...    ...
# 11696   LB         LB             Jagiellonia Białystok 2018 ~ 2021   6'1"
# 11697   GK         GK                      ESTAC Troyes 2019 ~ 2022   6'1"
# 11698   RM  LM CAM RM                    CD Antofagasta 2019 ~ 2024   5'6"
# 11699   CM        NaN                                 Barnsley 2010   6'2"
# 11700  CAM  ST CAM LM                  Portland Timbers 2019 ~ 2020   5'7"
#
#        Weight  ...   CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0      161lbs  ...  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1      159lbs  ...  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2      134lbs  ...  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
# 3      152lbs  ...  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2   59
# 4      150lbs  ...  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2   65
# ...       ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 11696  168lbs  ...  60+2  60+2  63+2  63+2  61+2  61+2  61+2  63+2  16+2   65
# 11697  174lbs  ...  26+2  26+2  25+2  24+2  26+2  26+2  26+2  24+2  69+2   70
# 11698  143lbs  ...  44+2  44+2  49+2  45+2  35+2  35+2  35+2  45+2  17+2   67
# 11699  179lbs  ...  68+0  68+0  66+0  64+0  60+0  60+0  60+0  64+0  25+0   68
# 11700  143lbs  ...  43+2  43+2  46+2  44+2  36+2  36+2  36+2  44+2  15+2   64
#
# [11701 rows x 101 columns]

# %%
data['Nationality'].unique()
# Out:
# array(['Switzerland', 'China PR', 'Italy', 'Wales', 'France',
#        'Bosnia Herzegovina', 'Argentina', 'Paraguay', 'Uruguay',
#        'United States', 'Mexico', 'Chile', 'Germany', 'Nigeria', 'Spain',
#        'Norway', 'Russia', 'England', 'Republic of Ireland', 'Cape Verde',
#        'Bulgaria', 'Zambia', 'Honduras', 'Albania', 'Finland', 'Ghana',
#        'Japan', 'Cameroon', 'Peru', 'Austria', 'Congo', 'Colombia',
#        'Belgium', 'Brazil', 'Korea Republic', 'Hungary', 'Morocco',
#        'Kosovo', 'Netherlands', 'Sweden', 'Scotland', 'Denmark',
#        'Northern Ireland', 'Turkey', 'Poland', 'Ivory Coast', 'Bolivia',
#        'Ukraine', 'Ecuador', 'Malaysia', 'DR Congo', 'Mali', 'Romania',
#        'Slovenia', 'United Arab Emirates', 'Australia', 'Venezuela',
#        'Montenegro', 'Slovakia', 'Curacao', 'Portugal', 'Senegal',
#        'Lebanon', 'Serbia', 'Iran', 'Zimbabwe', 'Iceland', 'Burkina Faso',
#        'Czech Republic', 'Iraq', 'Costa Rica', 'Canada', 'Libya', 'Benin',
#        'Korea DPR', 'Algeria', 'Angola', 'Saudi Arabia', 'Togo',
#        'South Sudan', 'Croatia', 'Comoros', 'Burundi', 'Vietnam',
#        'New Zealand', 'Greece', 'Jamaica', 'India', 'Lithuania', 'Aruba',
#        'Papua New Guinea', 'South Africa', 'Liberia', 'Haiti', 'Guyana',
#        'Guinea', 'Luxembourg', 'Egypt', 'Afghanistan', 'Tunisia',
#        'Uzbekistan', 'Equatorial Guinea', 'Georgia', 'Chinese Taipei',
#        'Dominican Republic', 'Indonesia', 'Moldova', 'Gambia', 'Cyprus',
#        'Cuba', 'Israel', 'Armenia', 'North Macedonia', 'Gabon', 'Kenya',
#        'Trinidad &amp; Tobago', 'Philippines', 'Azerbaijan', 'Latvia',
#        'Sudan', 'Mozambique', 'Panama', 'Antigua &amp; Barbuda',
#        'Mauritania', 'Liechtenstein', 'Madagascar', 'Guinea Bissau',
#        'Qatar', 'Uganda', 'Thailand', 'Faroe Islands',
#        'Saint Kitts and Nevis', 'Estonia', 'Grenada', 'Belarus', 'Guam',
#        'Sierra Leone', 'New Caledonia', 'Namibia', 'Jordan',
#        'Central African Republic', 'Syria', 'Macau', 'Kazakhstan',
#        'Malawi', 'Rwanda', 'Hong Kong', 'Singapore', 'Chad', 'Palestine',
#        'Barbados', 'Belize', 'Gibraltar', 'El Salvador', 'Malta',
#        'São Tomé &amp; Príncipe', 'Puerto Rico', 'Niger', 'Tanzania'],
#       dtype=object)

# %%
data['Weight'].unique()
# Out:
# array(['161lbs', '159lbs', '134lbs', '152lbs', '150lbs', '154lbs',
#        '192lbs', '163lbs', '172lbs', '130lbs', '170lbs', '157lbs',
#        '165lbs', '198lbs', '168lbs', '176lbs', '181lbs', '174lbs',
#        '123lbs', '179lbs', '196lbs', '190lbs', '194lbs', '141lbs',
#        '137lbs', '143lbs', '139lbs', '185lbs', '183lbs', '146lbs',
#        '187lbs', '132lbs', '148lbs', '126lbs', '207lbs', '216lbs',
#        '201lbs', '128lbs', '205lbs', '203lbs', '212lbs', '209lbs',
#        '227lbs', '225lbs', '121lbs', '117lbs', '220lbs', '214lbs',
#        '236lbs', '223lbs', '218lbs', '243lbs', '229lbs', '119lbs',
#        '234lbs'], dtype=object)

# %%
data['Age'].unique()
# Out:
# array([26, 30, 33, 22, 23, 34, 35, 37, 21, 27, 17, 28, 25, 24, 18, 20, 29,
#        32, 19, 31, 38, 36, 39, 42, 40, 41, 16, 43], dtype=int64)

# %%
def fill_na_with_mean(df, columns):
    df.fillna({col: df[col].mean() for col in columns}, inplace=True)

columns_to_fill = ['Volleys', 'Curve', 'Agility', 'Balance', 'Jumping', 'Interceptions', 'Positioning', 'Vision', 'Composure', 'Sliding Tackle']
fill_na_with_mean(data, columns_to_fill)
print(data.isna().sum())
# Out:
# ID              0
# Name            0
# Age             0
# Nationality     0
# Club           18
#                ..
# CB              0
# RCB             0
# RB              0
# GK              0
# OVA             0
# Length: 101, dtype: int64

# %%
data['Club'].unique()
# Out:
# array(['FC Lausanne-Sport', 'Beijing Sinobo Guoan FC', 'Al Hilal',
#        'Swansea City', 'US Orléans Loiret Football',
#        'Shanghai Greenland Shenhua FC', 'Parma', 'AC Monza', 'FC Lugano',
#        'Club Atlético Huracán', 'Olimpia Asunción',
#        'Nacional de Montevideo', 'New England Revolution', 'U.N.A.M.',
#        'Paris FC', 'Pachuca', 'FC St. Pauli', 'Lecce', 'FK Austria Wien',
#        'San Jose Earthquakes', 'Athletic Club de Bilbao', 'Odds BK',
#        'Argentinos Juniors', 'Spartak Moscow', 'Lincoln City', 'UCD AFC',
#        'Luton Town', 'Sporting CP', 'FC Porto', 'Bulgaria',
#        'SK Sturm Graz', 'Santos Laguna', 'Puebla FC', 'SV Meppen',
#        'HJK Helsinki', 'KAA Gent', 'VfL Osnabrück', 'Hatayspor',
#        'Gangwon FC', 'Club Atlético Talleres', 'Waasland-Beveren',
#        'Melgar FBC', 'New York Red Bulls', 'RC Strasbourg Alsace',
#        'FC Nantes', 'C.D. Castellón', 'Vitória Guimarães', 'LOSC Lille',
#        'Lazio', 'Oud-Heverlee Leuven', 'Doncaster Rovers',
#        'Club Libertad', 'FK Bodø/Glimt', 'Feyenoord', 'Hannover 96',
#        'Juventus', 'Busan IPark', 'SCR Altach', 'Club Atlético Grau',
#        'Villarreal CF', 'CA Osasuna', 'Hull City', 'Deportivo Alavés',
#        'Chelsea', 'SD Huesca', 'Torino', 'FC Cartagena',
#        'Borussia Mönchengladbach', 'PEC Zwolle', 'IFK Göteborg', 'Fulham',
#        'Santos', 'Deportivo Binacional', 'Shakhtar Donetsk',
#        'Houston Dynamo', 'FC Lorient', 'Spezia', 'Venezia FC',
#        'CD Feirense', 'Norwich City', 'Arsenal de Sarandí', 'Sagan Tosu',
#        'Sparta Rotterdam', 'Randers FC', 'UD Almería', 'Stabæk Fotball',
#        'Northampton Town', 'SpVgg Greuther Fürth', 'Fleetwood Town',
#        'São Paulo', 'Racing Santander', 'Patronato', '1. FC Nürnberg',
#        'Sunderland', 'Sassuolo', 'Bristol City', 'Eintracht Frankfurt',
#        nan, 'Grêmio', 'Udinese', 'Bolivia', 'Çaykur Rizespor',
#        'Eintracht Braunschweig', 'Accrington Stanley', 'Los Angeles FC',
#        'KV Kortrijk', 'Warta Poznań', 'AIK', 'Toronto FC',
#        'Manchester City', 'Cagliari', 'Jorge Wilstermann',
#        'Vélez Sarsfield', 'Kilmarnock', 'Chindia Târgovişte',
#        'Independiente', 'Varbergs BoIS', 'Universidad Católica',
#        '1. FC Saarbrücken', 'Salford City', 'RSC Anderlecht', 'Milan',
#        'FC Luzern', 'Bristol Rovers', 'Perugia', 'Derby County',
#        'Gimnasia y Esgrima La Plata', 'Leyton Orient', 'Chile',
#        'CF Fuenlabrada', 'DSC Arminia Bielefeld', 'Wycombe Wanderers',
#        'PFC CSKA Moscow', 'Real Zaragoza', 'Charlton Athletic',
#        'Legia Warszawa', 'Sheffield Wednesday', 'Mansfield Town',
#        'Virtus Entella', 'Walsall', 'Al Ain FC', 'Nîmes Olympique',
#        'Yokohama F. Marinos', 'UD Las Palmas', 'Bradford City',
#        'Willem II', 'Leicester City', 'KV Mechelen', 'VfL Wolfsburg',
#        'Delfín SC', 'Central Córdoba', 'RKC Waalwijk', 'Genoa',
#        'Hibernian', 'Orlando City SC', 'Atlético Bucaramanga',
#        'AS Monaco', 'UD Logroñés', 'Burnley', 'Nottingham Forest',
#        'Napoli', 'Nacional Asunción', '1. FC Union Berlin',
#        'Atlético Madrid', 'Columbus Crew SC', 'Millonarios FC', 'Cosenza',
#        'TSG 1899 Hoffenheim', 'VfB Lübeck', 'Querétaro', 'Rubin Kazan',
#        'Colo-Colo', 'Östersunds FK', 'Centro Atlético Fénix', 'Everton',
#        'Sligo Rovers', 'Royal Antwerp FC', 'Hamburger SV', 'Rio Ave FC',
#        'FC Bayern München', 'Os Belenenses', 'Estudiantes de La Plata',
#        'Yokohama FC', 'FC Metz', 'SV Darmstadt 98', 'Montreal Impact',
#        'Minnesota United FC', 'Olympiacos CFP', 'Viktoria Köln',
#        'Always Ready', 'Kayserispor', 'Valencia CF', 'OGC Nice',
#        'Portsmouth', 'Borussia Dortmund', 'Getafe CF', 'FC Emmen',
#        'Grenoble Foot 38', 'Real Sporting de Gijón', 'Stade de Reims',
#        'Derry City', 'Al Wehda', 'Northern Ireland',
#        'Paris Saint-Germain', 'FC Barcelona', 'Chievo Verona',
#        'Australia', 'SD Eibar', 'FC Pro Vercelli 1892',
#        'Heart of Midlothian', 'SK Brann', 'Boavista FC', 'Sampdoria',
#        'Exeter City', 'SC Verl', 'Rangers FC', 'Cádiz CF', 'Arsenal',
#        'Sangju Sangmu FC', 'SC Freiburg', 'Southend United',
#        'Vegalta Sendai', 'La Berrichonne de Châteauroux', 'Argentina',
#        'ADO Den Haag', 'Málaga CF', 'Le Havre AC', 'FC Nordsjælland',
#        'Club Tijuana', 'Barnsley', 'FC Utrecht', 'FC Red Bull Salzburg',
#        'Denizlispor', 'Huddersfield Town', 'Rosenborg BK', 'Chicago Fire',
#        'Portimonense SC', 'CD Leganés', 'Dijon FCO', 'Oita Trinita',
#        'Boca Juniors', 'Cardiff City', 'Carlisle United', 'Club América',
#        'KAS Eupen', 'Crystal Palace', 'MKE Ankaragücü', 'Oxford United',
#        'Defensa y Justicia', 'Göztepe SK', 'Aarhus GF',
#        'SV Zulte-Waregem', 'SG Dynamo Dresden', 'China PR', 'Vitesse',
#        'FC Admira Wacker Mödling', 'Stevenage', 'Valenciennes FC',
#        'New York City FC', 'Blackburn Rovers', 'KRC Genk', 'GFC Ajaccio',
#        '1. FSV Mainz 05', 'Deportes Tolima', 'VfL Bochum 1848',
#        'St. Johnstone FC', 'Bolton Wanderers', 'Mexico',
#        'Sporting de Charleroi', 'Club Atlas', 'SV Sandhausen',
#        'Morecambe', 'Cracovia', 'Malmö FF', 'Galatasaray SK',
#        'Manchester United', 'WSG Tirol', 'Hellas Verona',
#        'Tottenham Hotspur', 'Bournemouth', 'Newport County',
#        'Holstein Kiel', 'Coritiba', 'Ecuador', 'Extremadura UD',
#        'SL Benfica', 'Rotherham United', 'Brescia', 'Real Betis',
#        'FC Schalke 04', 'CD Tondela', 'Godoy Cruz', 'Stade Brestois 29',
#        'IFK Norrköping', 'RCD Espanyol', 'Lyngby BK', 'Pisa',
#        'Seongnam FC', 'SV Ried', 'Sparta Praha', 'Deportivo Pasto',
#        'Atlanta United', 'Club Atlético Aldosivi', 'Al Nassr',
#        'Alanyaspor', 'SK Slavia Praha', 'Birmingham City', 'Celtic',
#        'Liverpool', 'Internacional', 'Moreirense FC', 'Girona FC',
#        'Wolverhampton Wanderers', 'Fenerbahçe SK', 'FC Cincinnati',
#        'Clube Sport Marítimo', 'FC Augsburg', 'AEK Athens', 'Pescara',
#        'Milton Keynes Dons', 'Ascoli', 'Esbjerg fB', 'DC United',
#        'Pogoń Szczecin', 'RB Leipzig', 'FSV Zwickau', 'Colombia',
#        'Fatih Karagümrük S.K.', 'Palmeiras', 'Atlético Nacional',
#        'IK Start', 'Independiente Santa Fe', 'Fiorentina',
#        'Royal Excel Mouscron', 'Real Sociedad', 'Córdoba CF',
#        'Portland Timbers', 'Hallescher FC', 'Sevilla FC', 'SønderjyskE',
#        'Central Coast Mariners', 'Hokkaido Consadole Sapporo',
#        'Forest Green Rovers', 'Dinamo Zagreb', 'Lokomotiv Moscow',
#        'Tianjin TEDA FC', 'PAOK', 'KSV Cercle Brugge',
#        'Standard de Liège', 'Inter', 'Club Guaraní', 'FCSB (Steaua)',
#        'Cruzeiro', 'Rosario Central', 'SK Rapid Wien', 'LA Galaxy',
#        'Scunthorpe United', 'West Ham United', 'Deportivo Toluca',
#        'Barcelona Sporting Club', 'Cúcuta Deportivo', 'Club Necaxa',
#        'Watford', 'Dinamo Bucureşti', 'Heracles Almelo',
#        'AC Mineros de Guayana', 'Leeds United', 'Empoli', 'Benevento',
#        'Austria', 'Frosinone', 'Melbourne Victory', 'Granada CF',
#        'Incheon United FC', 'Western Sydney Wanderers', 'SKN St. Pölten',
#        'Famalicão', 'Rayo Vallecano', 'Cork City', 'Cusco FC',
#        'Kawasaki Frontale', 'AJ Auxerre', 'Beerschot AC', 'SC Heerenveen',
#        'Lechia Gdańsk', 'Cerezo Osaka', 'Paraguay', 'Shamrock Rovers',
#        'Vålerenga Fotball', 'Brentford', 'Ajax', 'SD Ponferradina',
#        'Club Atlético Tigre', 'Southampton', 'Odense Boldklub',
#        'Oldham Athletic', 'Harrogate Town', 'Dalian YiFang FC',
#        'FC Tokyo', 'Atlético Clube Goianiense', 'Macclesfield Town',
#        'Barrow', 'RC Celta', 'Cambridge United', 'Kashiwa Reysol',
#        'Caracas FC', 'New Zealand', 'Junior FC', 'Fortuna Düsseldorf',
#        'Stade Malherbe Caen', 'Yeni Malatyaspor',
#        'FC Girondins de Bordeaux', 'Itagüí Leones FC', 'Piast Gliwice',
#        'FC Ingolstadt 04', 'Shonan Bellmare', 'Atalanta', 'FC Basel 1893',
#        'FC Botoşani', 'Real Madrid', 'VfL Sportfreunde Lotte',
#        'Brighton & Hove Albion', 'Alianza Lima', 'Karlsruher SC',
#        'FC St. Gallen', 'TSV 1860 München', 'Coventry City',
#        'Orlando Pirates', 'Al Taawoun', 'Górnik Zabrze',
#        'Newcastle United', 'Vejle Boldklub', 'Club Athletico Paranaense',
#        'Wellington Phoenix', 'River Plate', 'Dynamo Kyiv', 'Roma',
#        'FC København', 'Beşiktaş JK', 'KFC Uerdingen 05', 'Farense',
#        'SC Beira Mar', 'Toulouse Football Club', 'Sporting Kansas City',
#        'Molde FK', 'FC Krasnodar', 'FC Würzburger Kickers',
#        'Olympique de Marseille', 'Hamilton Academical FC',
#        '1. FC Kaiserslautern', 'SSV Jahn Regensburg',
#        'Independiente Medellín', 'SV Werder Bremen', 'PSV',
#        'Mjøndalen IF', 'Nashville SC', 'VVV-Venlo', 'Peterborough United',
#        'Club Atlético Lanús', 'Tiburones Rojos de Veracruz',
#        'West Bromwich Albion', 'Emelec', 'Nagoya Grampus', 'LDU Quito',
#        'Al Shabab', 'SpVgg Unterhaching', 'SC Braga', 'Lech Poznań',
#        'Guangzhou Evergrande Taobao FC', 'Slovenia', 'ESTAC Troyes',
#        'Aston Villa', 'FC Paços de Ferreira', 'AS Saint-Étienne',
#        'Servette FC', 'Racing Club', 'Kaizer Chiefs', 'Ettifaq FC',
#        'Jiangsu Suning FC', 'Montpellier HSC', 'SC Paderborn 07',
#        'Al Fateh', 'Deportivo de La Coruña', 'Viktoria Plzeň',
#        'RCD Mallorca', 'FC Sochaux-Montbéliard', 'Adelaide United',
#        'CD Tenerife', 'Helsingborgs IF', 'Canada', 'AS Nancy Lorraine',
#        'Vancouver Whitecaps FC', 'FC Dallas', 'Shelbourne FC',
#        'Gimnàstic de Tarragona', 'Sheffield United',
#        'Jeonbuk Hyundai Motors', 'CD Lugo', 'Albacete BP',
#        'Medipol Başakşehir FK', 'Antalyaspor', 'Hungary',
#        'Real Salt Lake', 'Colorado Rapids', 'Atiker Konyaspor',
#        'Türkgücü München', 'Mjällby AIF', 'Sint-Truidense VV',
#        'Guadalajara', 'FC Argeș', 'Amiens SC', 'Bologna', 'Flamengo',
#        'Pau FC', 'IF Elfsborg', 'Kristiansund BK', 'Colchester United',
#        'River Plate Montevideo', 'Estudiantes de Mérida',
#        'Racing Club de Lens', 'Castellammare di Stabia', 'LASK Linz',
#        'Club Atlético Banfield', 'Qingdao Huanghai F.C.',
#        'Guangzhou R&F FC', 'Peñarol', 'Trabzonspor', 'VfB Stuttgart',
#        'South Africa', 'Unión Magdalena', 'Gil Vicente FC',
#        'Macarthur FC', 'Egypt', 'Cheltenham Town', 'Uruguay',
#        'Gillingham', 'Romania', 'Scotland', '1. FC Heidenheim 1846',
#        'Mazatlán FC', 'Bahia', 'Bayer 04 Leverkusen',
#        'San Lorenzo de Almagro', 'Crewe Alexandra', 'Sandefjord Fotball',
#        'CE Sabadell FC', 'Club Bolívar', 'Chacarita Juniors',
#        'Al Ittihad', 'Club Brugge KV', 'Viking FK', 'SV Wehen Wiesbaden',
#        'GwangJu FC', 'Club Plaza Colonia', 'FC Vaduz', 'Ohod Club',
#        'SPAL', 'Atlético Tucumán', 'Kashima Antlers', 'Levante UD',
#        'Zagłębie Lubin', 'Independiente del Valle', 'Swindon Town',
#        'En Avant de Guingamp', 'Sivasspor', 'Aberdeen', 'Crawley Town',
#        'Stade Lavallois Mayenne FC', 'Motherwell', 'Bayern München II',
#        'Al Fayha', 'Panathinaikos FC', "Newell's Old Boys",
#        'Shandong Luneng TaiShan FC', 'FC Erzgebirge Aue', 'CD Nacional',
#        'US Cremonese', 'CD Mirandés', 'Philadelphia Union', 'Cameroon',
#        'India', "St. Patrick's Athletic", 'Henan Jianye FC', 'FC Juárez',
#        'Chamois Niortais Football Club', 'Abha Club', 'Falkenbergs FF',
#        'SV Waldhof Mannheim', 'Port Vale', 'BK Häcken', 'Grimsby Town',
#        'USL Dunkerque', 'Monterrey', 'Örebro SK', 'Sydney FC',
#        'Stade Rennais FC', 'Yeovil Town', 'Trapani',
#        'CD Everton de Viña del Mar', 'Santa Clara', 'Sanfrecce Hiroshima',
#        'Hertha BSC', 'América de Cali', 'Ipswich Town', 'Russia',
#        'Switzerland', 'KV Oostende', 'Ceará Sporting Club', 'Shenzhen FC',
#        'Vissel Kobe', 'Real Valladolid CF', 'River Plate Asunción',
#        'Cruz Azul', 'Unión de Santa Fe', 'Real Oviedo', '1. FC Köln',
#        'Reading', 'Daegu FC', 'Blackpool', 'Crotone', 'Hammarby IF',
#        'Dundee United', 'Brøndby IF', 'St. Mirren', 'SC Preußen Münster',
#        'Dundalk', 'Elche CF', 'Bursaspor', 'Jeju United FC',
#        'FK Haugesund', 'Barnet', 'Hobro IK', 'Fortaleza',
#        'US Salernitana 1919', 'Club Blooming', 'BSC Young Boys',
#        'Waterford FC', 'Grasshopper Club Zürich', 'Sepsi OSK',
#        'Atlético de San Luis', 'Melbourne City FC', 'Kasimpaşa SK',
#        'Brazil', 'Fortuna Sittard', 'IK Sirius', 'Sweden', 'Silkeborg IF',
#        'FC Groningen', 'Olympique Lyonnais', 'CD Aves', 'Burton Albion',
#        'Middlesbrough', 'Sarpsborg 08 FF', 'Gamba Osaka',
#        'Tigres U.A.N.L.', 'MSV Duisburg', 'Germany', 'Brisbane Roar',
#        'Kalmar FF', 'Al Batin', 'Raków Częstochowa', 'FC Midtjylland',
#        'Podbeskidzie Bielsko-Biała', 'Bohemian FC', 'Angers SCO',
#        'Finn Harps', 'Sol de América', '1. FC Magdeburg', 'Rochdale',
#        'Wuhan Zall', 'Preston North End', 'Damac FC', 'Sakaryaspor',
#        'Atlético Mineiro', 'Al Hazem', 'AC Ajaccio', 'FC Sion',
#        'Vasco da Gama', 'Inter Miami', 'Sport Huancayo', 'CD Huachipato',
#        'Clermont Foot 63', 'Jagiellonia Białystok', 'Aragua FC',
#        'Al Faisaly', 'Goiás', 'Seattle Sounders FC', 'Millwall',
#        'FC Viitorul', 'Liverpool Fútbol Club', 'Sportivo Luqueño',
#        'Stoke City', 'FC Zürich', 'Pohang Steelers', 'Nacional Potosí',
#        'Queens Park Rangers', 'Universitatea Craiova', 'Fluminense',
#        'Roda JC Kerkrade', 'Peru', 'Botafogo', 'AZ Alkmaar',
#        'Astra Giurgiu', 'Djurgårdens IF', 'AD Alcorcón', 'Tromsø IL',
#        'FC Twente', 'Vitória de Setúbal', 'SD Aucas', 'CFR Cluj',
#        'Wisła Kraków', 'Aalesunds FK', 'Zamora FC', 'Al Raed',
#        'Wolfsberger AC', 'Zenit St. Petersburg', 'Longford Town',
#        'FC Chambly Oise', 'Universidad de Chile', 'Bray Wanderers',
#        'Deportes Iquique', 'Wisła Płock', 'Modena', 'Livorno',
#        'Plymouth Argyle', 'Western United FC', 'Academica Clinceni',
#        'Ross County FC', 'Shijiazhuang Ever Bright F.C.',
#        'BB Erzurumspor', 'Venezuela', 'Unión La Calera', 'De Graafschap',
#        'FC Thun', 'Club León', 'Strømsgodset IF', 'Lillestrøm SK',
#        'SG Sonnenhof Großaspach', 'Newcastle Jets', 'Stal Mielec',
#        'Amkar Perm', 'CD Antofagasta', 'FC Hansa Rostock', 'Notts County',
#        'CD Cobresal', 'Tianjin Quanjian FC', 'Rionegro Águilas',
#        'Deportivo Cali', 'Gaz Metan Mediaş', 'AC Horsens',
#        'Club Atlético Colón', 'Monarcas Morelia', 'Ulsan Hyundai FC',
#        'Chongqing Dangdai Lifan FC SWM Team', 'SC Fortuna Köln',
#        'FC Voluntari', 'Livingston FC', "Côte d'Ivoire",
#        'Gençlerbirliği SK', 'Once Caldas', 'FC Seoul', 'Tranmere Rovers',
#        'Urawa Red Diamonds', 'AFC Wimbledon', 'Suwon Samsung Bluewings',
#        'Estoril Praia', 'Wigan Athletic', 'Gazişehir Gaziantep F.K.',
#        'Politehnica Iaşi', 'Unión Española', 'La Equidad',
#        'Coquimbo Unido', 'El Nacional', 'Vitória', 'Netherlands',
#        'Belgium', 'CD Numancia', 'TSV Hartberg', 'Beijing Renhe FC',
#        'Cittadella', 'Oceânico FC', 'Aalborg BK', 'Chemnitzer FC',
#        'Greece', 'Universidad Católica del Ecuador',
#        'CD Universidad de Concepción', 'Figueirense', 'FC Aarau',
#        'Alianza Petrolera', 'Norway', 'Halmstads BK', 'Arsenal Tula',
#        'CD Palestino', 'Al Adalah', 'Shrewsbury', 'Al Ahli',
#        'Hebei China Fortune FC', 'US Créteil-Lusitanos', 'Perth Glory',
#        'Rodez Aveyron Football', 'Guizhou Hengfeng FC', 'Audax Italiano',
#        'Shimizu S-Pulse', 'Śląsk Wrocław', 'FC Carl Zeiss Jena',
#        'Osmanlıspor', 'Portugal', 'SKA Khabarovsk', 'Patriotas Boyacá FC',
#        'Envigado FC', 'FC Hermannstadt', 'Triestina', 'Curicó Unido',
#        'FC Rostov', 'UTA Arad', 'Excelsior', 'Le Mans FC',
#        'Sporting Club de Bastia', 'Iceland', 'Ukraine',
#        'San Martín de San Juan', 'Vicenza', 'LKS Lodz', 'Kuban Krasnodar',
#        'Adanaspor', 'Shanghai SIPG FC', 'Gyeongnam FC', 'FC Orenburg',
#        'Ponte Preta', 'GIF Sundsvall', 'Sporting Lokeren', 'FC Tosno',
#        'Finland', 'Dorados de Sinaloa', 'Atlante', 'AC Arles Avignon',
#        'Pordenone', 'Terek Grozny', 'Kardemir Karabükspor',
#        'Eskişehirspor', 'Zagłębie Sosnowiec', 'Jaguares de Córdoba',
#        'Chivas USA', 'Wales', 'Atlético Huila', 'Oriente Petrolero',
#        'Chapecoense', 'Júbilo Iwata', 'Quilmes Atlético Club',
#        'Albirex Niigata', 'FC Istres Ouest Provence',
#        'Bruk-Bet Termalica Nieciecza', 'Neuchâtel Xamax', 'Spain',
#        'Associação Académica de Coimbra', 'Tours FC', 'CA Bastia',
#        'Partick Thistle FC', 'Arka Gdynia', 'Al Qadisiyah',
#        'Changchun Yatai FC', 'Llaneros de Guanare', 'Czech Republic',
#        'Korona Kielce', 'San Martin de Tucumán', 'Lierse SK',
#        'CF Rayo Majadahonda', 'Évian Thonon Gaillard FC', 'AS Béziers',
#        'FC Anzhi Makhachkala', 'Paraná', 'VfR Aalen', "CD O'Higgins",
#        'Krylya Sovetov Samara', 'Como', 'Bari', 'United States',
#        'NAC Breda', 'Jaguares de Chiapas', 'Cesena',
#        'FC Ural Yekaterinburg', 'Go Ahead Eagles', 'Red Star FC',
#        'Denmark', 'Wexford Youths', 'Santo André'], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 data = cleanfifa(data)
#       2 data
#
# Cell In[73], line 2, in cleanfifa(data)
#       1 def cleanfifa(data):
# ----> 2     data = data.drop_duplicates()
#       3     mean_value=data.mean()
#       4     data.fillna(value=mean_value, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop_duplicates'
